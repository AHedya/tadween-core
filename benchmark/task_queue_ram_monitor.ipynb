# %%
import logging

logging.basicConfig(level=logging.INFO, force=True)

from tadween_core.devtools.analytics.plot import RAMPlotter  # noqa
from tadween_core.devtools.analytics.processors import RAMSessionProcessor  # noqa


batch = tuple(
    RAMSessionProcessor.from_file(
        "/home/projects/tadween/core/benchmark/results/RAM_100mb.log"
    )
)
plotter = RAMPlotter(batch)

# %%
plotter.plot(
    indexes=list(range(3)),
)

# %%
plotter.plot(indexes=list(range(3, 6)), include_children=True)

# %%
plotter.plot(indexes=list(range(6, 9)), include_children=True)

# %%
plotter.plot(indexes=list(range(9, 12)), include_children=False)

# %%
plotter.plot(indexes=list(range(12, 15)), include_children=True)

# %%
plotter.plot(indexes=list(range(15, 18)), include_children=True)
