# %%
import logging
from pathlib import Path

logging.basicConfig(level=logging.INFO, force=True)

from tadween_core.devtools.analytics.plot import MemoryPlotter  # noqa
from tadween_core.devtools.analytics.processors import MemorySessionProcessor  # noqa
from tadween_core.devtools.analytics.loaders import load_memory_sessions  # noqa


path = Path("/home/projects/tadween/core/benchmark/results/ref.log")
batch = tuple(MemorySessionProcessor.from_file(path))
plotter = MemoryPlotter(batch)

# %%
plotter.plot(show_details=True, show_peak=False, include_children=True)

# %%
plotter.plot(show_details=False, show_peak=False, include_children=True)

# %%
plotter.plot(show_details=True, show_peak=False, include_children=True)
