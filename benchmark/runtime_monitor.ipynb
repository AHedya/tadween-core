# %%
import logging
from pathlib import Path

logging.basicConfig(level=logging.INFO, force=True)

import polars as pl  # noqa
from tadween_core.devtools.analytics.plot import RuntimePlotter  # noqa
from tadween_core.devtools.analytics.processors import RuntimeSessionProcessor  # noqa

pth = Path("/home/projects/tadween/core/benchmark/results/bottleneck_CPU_numpy.log")
batch = list(RuntimeSessionProcessor.from_file(pth))
plotter = RuntimePlotter(batch)

# %%
fig = plotter.plot(
    # indexes=[0, 4, 6],
    sort_by_duration=True,
    show_details=True,
    show_stage_stats=True,
    share_x=True,
    dpi=500,
)
fig.savefig(pth.with_suffix(".png"))
